# %%
import sys
from RecQ import RecQ
from tool.config import Config
from visual.display import Display



if __name__ == '__main__':

    print '='*80
    print '   RecQ: An effective python-based recommender algorithm library.   '
    print '='*80
    print '0. Analyze the input data.(Configure the visual.conf in config/visual first.)'
    print '-' * 80
    print 'Generic Recommenders:'
    print '1. UserKNN        2. ItemKNN        3. BasicMF        4. SlopeOne        5. SVD'
    print '6. PMF            7. SVD++          8. EE             9. BPR             10. WRMF'
    print '11. ExpoMF'

    print 'Social Recommenders:'
    print 's1. RSTE          s2. SoRec         s3. SoReg         s4. SocialMF       s5. SBPR'
    print 's6. SREE          s7. LOCABAL       s8. SocialFD      s9. TBPR           s10. SERec'

    print 'Network Embedding based Recommenders:'
    print 'a1. CoFactor      a2. CUNE-MF       a3. CUNE-BPR      a4. IF-BPR'

    print 'Deep Recommenders:'
    print 'd1. APR           d2. CDAE          d3. DMF           d4. NeuMF           d5. CFGAN'
    print 'd6. IRGAN         d7. RSGAN         d8. NGCF          d9. AGR'

    print 'Baselines:'
    print 'b1. UserMean      b2. ItemMean      b3. MostPopular   b4. Rand'


    print '='*80
    algor = -1
    conf = -1
    order = raw_input('please enter the num of the algorithm to run it:')
    import time
    s = time.time()
    if order == '0':
        try:
            import seaborn as sns
        except ImportError:
            print '!!!To obtain nice data charts, ' 
                  'we strongly recommend you to install the third-party package <seaborn>!!!'
        conf = Config('../config/visual/visual.conf')
        Display(conf).render()
        exit(0)

    algorthms = {'1':'UserKNN','2':'ItemKNN','3':'BasicMF','4':'SlopeOne','5':'SVD','6':'PMF',
                 '7':'SVD++','8':'EE','9':'BPR','10':'WRMF','11':'ExpoMF',
                 's1':'RSTE','s2':'SoRec','s3':'SoReg','s4':'SocialMF','s5':'SBPR','s6':'SREE',
                 's7':'LOCABAL','s8':'SocialFD','s9':'TBPR','s10':'SEREC','a1':'CoFactor',
                 'a2':'CUNE_MF','a3':'CUNE_BPR','a4':'IF_BPR',
                 'd1':'APR','d2':'CDAE','d3':'DMF','d4':'NeuMF','d5':'CFGAN','d6':'IRGAN','d7':'RSGAN','d8':'NGCF',
                 'd9':'AGR',
                 'b1':'UserMean','b2':'ItemMean','b3':'MostPopular','b4':'Rand'}

    try:
        conf = Config('/home/songxuan/python/RecQ/config/'+algorthms[order]+'.conf')
    except KeyError:
        print 'Error num!'
        exit(-1)
    recSys = RecQ(conf)
    recSys.execute()
    e = time.time()
    print "Run time: %f s" % (e - s)
# Out:
# ================================================================================
#    RecQ: An effective python-based recommender algorithm library.
# ================================================================================
# 0. Analyze the input data.(Configure the visual.conf in config/visual first.)
# --------------------------------------------------------------------------------
# Generic Recommenders:
# 1. UserKNN        2. ItemKNN        3. BasicMF        4. SlopeOne        5. SVD
# 6. PMF            7. SVD++          8. EE             9. BPR             10. WRMF
# 11. ExpoMF
# Social Recommenders:
# s1. RSTE          s2. SoRec         s3. SoReg         s4. SocialMF       s5. SBPR
# s6. SREE          s7. LOCABAL       s8. SocialFD      s9. TBPR           s10. SERec
# Network Embedding based Recommenders:
# a1. CoFactor      a2. CUNE-MF       a3. CUNE-BPR      a4. IF-BPR
# Deep Recommenders:
# d1. APR           d2. CDAE          d3. DMF           d4. NeuMF           d5. CFGAN
# d6. IRGAN         d7. RSGAN         d8. NGCF          d9. AGR
# Baselines:
# b1. UserMean      b2. ItemMean      b3. MostPopular   b4. Rand
# ================================================================================
# please enter the num of the algorithm to run it:a4
# loading training data...
# loading social data...
# The social file is not in a correct format.
# preprocessing...
# Algorithm: IF_BPR
# Ratings dataset: /home/songxuan/python/RecQ/dataset/doubanmovie/ratings.txt
# Training set size: (user count: 1351, item count 1995, record count: 35098)
# Test set size: (user count: 1088, item count 1408, record count: 8775)
# ================================================================================
# Reduced Dimension: 50
# Maximum Iteration: 30
# Regularization parameter: regU 0.010, regI 0.010, regB 0.010
# ================================================================================
# Social dataset: /home/songxuan/python/RecQ/dataset/doubanmovie/trust.txt
# Social size  (User count: 1919 Trust statement count:1560)
# Social Regularization parameter: regS 0.200
# ================================================================================
# Specified Arguments of IF_BPR:
# Walks count per user 2
# Length of each walk 20
# Dimension of user embedding 20
# ================================================================================
# Initializing model [1]...
# Preparing item sets...
# Building Model [1]...
# Kind Note: This method will probably take much time.
# Building weighted user-friend network...
# Generating random meta-path random walks... (Positive)
# pwalks: 39064
# nwalks: 39457
# Generating user embedding...
# User embedding generated.
# Constructing similarity matrix...
# 200 / 1384
# 400 / 1384
# 600 / 1384
# 800 / 1384
# 1000 / 1384
# 1200 / 1384
# 200 / 1384
# 400 / 1384
# 600 / 1384
# 800 / 1384
# 1000 / 1384
# 1200 / 1384
# Decomposing...
# IF_BPR [1] iteration 1: loss = 116557.9034, delta_loss = -116557.90345 learning_Rate = 0.05000
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1046
# Recall:0.173762803139
# F1:0.130589209502
# MAP:0.0882850314941
# NDCG:0.164991621151
# Top 20
# Precision:0.08345
# Recall:0.258777057859
# F1:0.126202443567
# MAP:0.0921101518114
# NDCG:0.190414098078
# --------------------------------------------------------------------------------
# [1] iteration: 1
# IF_BPR [1] iteration 2: loss = 113791.3503, delta_loss = 2766.55312 learning_Rate = 0.05000
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1017
# Recall:0.171328677546
# F1:0.127635870803
# MAP:0.0875321261653
# NDCG:0.161859220448
# Top 20
# Precision:0.08315
# Recall:0.265886755143
# F1:0.126682839927
# MAP:0.0924766259917
# NDCG:0.190853400219
# --------------------------------------------------------------------------------
# [1] iteration: 2
# IF_BPR [1] iteration 3: loss = 113239.2067, delta_loss = 552.14365 learning_Rate = 0.05250
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1038
# Recall:0.176527595341
# F1:0.130729651315
# MAP:0.0887224252016
# NDCG:0.165537692661
# Top 20
# Precision:0.0845
# Recall:0.26130673402
# F1:0.12770381171
# MAP:0.0927827015304
# NDCG:0.191485262794
# --------------------------------------------------------------------------------
# [1] iteration: 3
# IF_BPR [1] iteration 4: loss = 112624.5247, delta_loss = 614.68195 learning_Rate = 0.05513
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1094
# Recall:0.177987665473
# F1:0.135509299403
# MAP:0.0917671745087
# NDCG:0.169728364564
# Top 20
# Precision:0.0858
# Recall:0.268807117688
# F1:0.130080021225
# MAP:0.0950560206929
# NDCG:0.195582917284
# --------------------------------------------------------------------------------
# [1] iteration: 4
# IF_BPR [1] iteration 5: loss = 111837.1624, delta_loss = 787.36231 learning_Rate = 0.05788
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1116
# Recall:0.186817914603
# F1:0.139729407984
# MAP:0.0925826210947
# NDCG:0.173217441177
# Top 20
# Precision:0.09095
# Recall:0.282659897521
# F1:0.137619039807
# MAP:0.0978783995251
# NDCG:0.202663896079
# --------------------------------------------------------------------------------
# [1] iteration: 5
# IF_BPR [1] iteration 6: loss = 111011.0678, delta_loss = 826.09457 learning_Rate = 0.06078
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1177
# Recall:0.188799213136
# F1:0.145003095824
# MAP:0.0980269742063
# NDCG:0.180037266096
# Top 20
# Precision:0.09095
# Recall:0.277152668765
# F1:0.136956546981
# MAP:0.100820590433
# NDCG:0.204730722019
# --------------------------------------------------------------------------------
# [1] iteration: 6
# IF_BPR [1] iteration 7: loss = 110109.0179, delta_loss = 902.04999 learning_Rate = 0.06381
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1179
# Recall:0.193797578382
# F1:0.146608354225
# MAP:0.100633081538
# NDCG:0.184489934395
# Top 20
# Precision:0.09415
# Recall:0.297788600889
# F1:0.143067290183
# MAP:0.105153378886
# NDCG:0.21465704915
# --------------------------------------------------------------------------------
# [1] iteration: 7
# IF_BPR [1] iteration 8: loss = 109622.9637, delta_loss = 486.05419 learning_Rate = 0.06700
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1189
# Recall:0.191821780908
# F1:0.146804061713
# MAP:0.102394522707
# NDCG:0.186101834615
# Top 20
# Precision:0.0941
# Recall:0.293885294493
# F1:0.1425549195
# MAP:0.106383773364
# NDCG:0.215249907154
# --------------------------------------------------------------------------------
# [1] iteration: 8
# IF_BPR [1] iteration 9: loss = 109192.6886, delta_loss = 430.27508 learning_Rate = 0.07036
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1221
# Recall:0.201742311883
# F1:0.152127967082
# MAP:0.102989375787
# NDCG:0.189581813687
# Top 20
# Precision:0.09535
# Recall:0.297864693299
# F1:0.14445746301
# MAP:0.107128625158
# NDCG:0.217159743715
# --------------------------------------------------------------------------------
# [1] iteration: 9
# IF_BPR [1] iteration 10: loss = 109227.6955, delta_loss = -35.00690 learning_Rate = 0.07387
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1209
# Recall:0.199607859937
# F1:0.150589693939
# MAP:0.100840842467
# NDCG:0.187150931092
# Top 20
# Precision:0.0947
# Recall:0.293166306966
# F1:0.143156797954
# MAP:0.10411992756
# NDCG:0.213929979446
# --------------------------------------------------------------------------------
# [1] iteration: 10
# IF_BPR [1] iteration 11: loss = 105328.5537, delta_loss = 3899.14183 learning_Rate = 0.03694
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1252
# Recall:0.205792335102
# F1:0.155684574066
# MAP:0.110300301871
# NDCG:0.199288240225
# Top 20
# Precision:0.0981
# Recall:0.307543173372
# F1:0.148751352362
# MAP:0.113999432085
# NDCG:0.227692828606
# --------------------------------------------------------------------------------
# [1] iteration: 11
# IF_BPR [1] iteration 12: loss = 104933.9472, delta_loss = 394.60648 learning_Rate = 0.03878
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1277
# Recall:0.209927842518
# F1:0.158800798474
# MAP:0.108939735607
# NDCG:0.199316042083
# Top 20
# Precision:0.0987
# Recall:0.308940687883
# F1:0.149604525752
# MAP:0.112870502644
# NDCG:0.226993703653
# --------------------------------------------------------------------------------
# [1] iteration: 12
# IF_BPR [1] iteration 13: loss = 104373.3281, delta_loss = 560.61907 learning_Rate = 0.04072
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1305
# Recall:0.212220970529
# F1:0.161617403285
# MAP:0.108587197027
# NDCG:0.199814144829
# Top 20
# Precision:0.10075
# Recall:0.312812187393
# F1:0.15241155425
# MAP:0.112674341451
# NDCG:0.22783871132
# --------------------------------------------------------------------------------
# [1] iteration: 13
# IF_BPR [1] iteration 14: loss = 104191.9338, delta_loss = 181.39434 learning_Rate = 0.04276
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1302
# Recall:0.215962391557
# F1:0.162457297884
# MAP:0.109105057162
# NDCG:0.202142624135
# Top 20
# Precision:0.09965
# Recall:0.309905612386
# F1:0.15080781872
# MAP:0.112616378997
# NDCG:0.22785623546
# --------------------------------------------------------------------------------
# [1] iteration: 14
# IF_BPR [1] iteration 15: loss = 104292.2185, delta_loss = -100.28478 learning_Rate = 0.04490
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1244
# Recall:0.209129811184
# F1:0.156002537938
# MAP:0.108154888511
# NDCG:0.197188199241
# Top 20
# Precision:0.0973
# Recall:0.306485116161
# F1:0.147707285925
# MAP:0.112191818201
# NDCG:0.224827212711
# --------------------------------------------------------------------------------
# [1] iteration: 15
# IF_BPR [1] iteration 16: loss = 102071.0666, delta_loss = 2221.15198 learning_Rate = 0.02245
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.129
# Recall:0.206643270725
# F1:0.158841152191
# MAP:0.111261791226
# NDCG:0.202114824905
# Top 20
# Precision:0.10115
# Recall:0.314498415164
# F1:0.15306934194
# MAP:0.115527332095
# NDCG:0.23198037221
# --------------------------------------------------------------------------------
# [1] iteration: 16
# IF_BPR [1] iteration 17: loss = 101679.7464, delta_loss = 391.32013 learning_Rate = 0.02357
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1312
# Recall:0.211914338328
# F1:0.162063534413
# MAP:0.111480548154
# NDCG:0.203242318956
# Top 20
# Precision:0.10095
# Recall:0.312338990481
# F1:0.152583890765
# MAP:0.114503854933
# NDCG:0.230204215625
# --------------------------------------------------------------------------------
# [1] iteration: 17
# IF_BPR [1] iteration 18: loss = 101731.2166, delta_loss = -51.47017 learning_Rate = 0.02475
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1291
# Recall:0.209666996684
# F1:0.159803106778
# MAP:0.111752216711
# NDCG:0.202997543777
# Top 20
# Precision:0.10135
# Recall:0.316445715249
# F1:0.153528492849
# MAP:0.11566971997
# NDCG:0.232407245478
# --------------------------------------------------------------------------------
# [1] iteration: 18
# IF_BPR [1] iteration 19: loss = 100581.2695, delta_loss = 1149.94709 learning_Rate = 0.01237
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1324
# Recall:0.211481147592
# F1:0.162847566011
# MAP:0.113732012944
# NDCG:0.205732760092
# Top 20
# Precision:0.1018
# Recall:0.31575771543
# F1:0.153962598429
# MAP:0.116912935377
# NDCG:0.233621861259
# --------------------------------------------------------------------------------
# [1] iteration: 19
# IF_BPR [1] iteration 20: loss = 100317.8887, delta_loss = 263.38081 learning_Rate = 0.01299
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1344
# Recall:0.214531936606
# F1:0.165264851136
# MAP:0.113380131015
# NDCG:0.207409558066
# Top 20
# Precision:0.10265
# Recall:0.317271047512
# F1:0.155114268361
# MAP:0.116528567697
# NDCG:0.234515610323
# --------------------------------------------------------------------------------
# [1] iteration: 20
# IF_BPR [1] iteration 21: loss = 100260.8684, delta_loss = 57.02035 learning_Rate = 0.01364
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1347
# Recall:0.214042747716
# F1:0.165345707151
# MAP:0.114566221655
# NDCG:0.208264122459
# Top 20
# Precision:0.10215
# Recall:0.316388785833
# F1:0.154437846942
# MAP:0.117748590589
# NDCG:0.235187381324
# --------------------------------------------------------------------------------
# [1] iteration: 21
# IF_BPR [1] iteration 22: loss = 100137.8813, delta_loss = 122.98704 learning_Rate = 0.01433
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1344
# Recall:0.215563872912
# F1:0.165570144588
# MAP:0.11452360434
# NDCG:0.208479149992
# Top 20
# Precision:0.10285
# Recall:0.319983300115
# F1:0.15566551834
# MAP:0.118629102845
# NDCG:0.236651986809
# --------------------------------------------------------------------------------
# [1] iteration: 22
# IF_BPR [1] iteration 23: loss = 100308.7969, delta_loss = -170.91554 learning_Rate = 0.01504
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1345
# Recall:0.215061739686
# F1:0.165497539941
# MAP:0.113958444822
# NDCG:0.20781916937
# Top 20
# Precision:0.10465
# Recall:0.325586432012
# F1:0.158390213263
# MAP:0.118804099185
# NDCG:0.238448036889
# --------------------------------------------------------------------------------
# [1] iteration: 23
# IF_BPR [1] iteration 24: loss = 99534.2035, delta_loss = 774.59333 learning_Rate = 0.00752
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1351
# Recall:0.216966789812
# F1:0.166515071298
# MAP:0.115789813398
# NDCG:0.209972027303
# Top 20
# Precision:0.1038
# Recall:0.322502639091
# F1:0.157051685202
# MAP:0.119993706557
# NDCG:0.238740714822
# --------------------------------------------------------------------------------
# [1] iteration: 24
# IF_BPR [1] iteration 25: loss = 99451.5718, delta_loss = 82.63174 learning_Rate = 0.00790
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1365
# Recall:0.21882046876
# F1:0.168124251834
# MAP:0.116915615867
# NDCG:0.211702047121
# Top 20
# Precision:0.10395
# Recall:0.320358495024
# F1:0.156967234681
# MAP:0.120240507303
# NDCG:0.238533489257
# --------------------------------------------------------------------------------
# [1] iteration: 25
# IF_BPR [1] iteration 26: loss = 99546.3389, delta_loss = -94.76711 learning_Rate = 0.00829
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1378
# Recall:0.219683087758
# F1:0.169363701555
# MAP:0.115912250252
# NDCG:0.211092333884
# Top 20
# Precision:0.10415
# Recall:0.321083537567
# F1:0.157282281303
# MAP:0.119267381015
# NDCG:0.237982414172
# --------------------------------------------------------------------------------
# [1] iteration: 26
# IF_BPR [1] iteration 27: loss = 99034.3573, delta_loss = 511.98162 learning_Rate = 0.00415
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1372
# Recall:0.217071866138
# F1:0.168132233354
# MAP:0.115542797462
# NDCG:0.210411657278
# Top 20
# Precision:0.1041
# Recall:0.322866535499
# F1:0.15743812946
# MAP:0.118979895929
# NDCG:0.23851264841
# --------------------------------------------------------------------------------
# [1] iteration: 27
# IF_BPR [1] iteration 28: loss = 99064.4546, delta_loss = -30.09730 learning_Rate = 0.00435
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1381
# Recall:0.218233415608
# F1:0.169156376446
# MAP:0.116058798973
# NDCG:0.211029522538
# Top 20
# Precision:0.1041
# Recall:0.323388810592
# F1:0.157500146664
# MAP:0.119225675986
# NDCG:0.238422777875
# --------------------------------------------------------------------------------
# [1] iteration: 28
# IF_BPR [1] iteration 29: loss = 98745.2305, delta_loss = 319.22404 learning_Rate = 0.00218
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1379
# Recall:0.217435307911
# F1:0.168766392156
# MAP:0.117649595459
# NDCG:0.212085298663
# Top 20
# Precision:0.104
# Recall:0.322970988318
# F1:0.157336136197
# MAP:0.12059641984
# NDCG:0.239484694004
# --------------------------------------------------------------------------------
# [1] iteration: 29
# IF_BPR [1] iteration 30: loss = 98794.0316, delta_loss = -48.80111 learning_Rate = 0.00229
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1393
# Recall:0.219558488805
# F1:0.170454362623
# MAP:0.118242546296
# NDCG:0.213404939852
# Top 20
# Precision:0.1043
# Recall:0.324320114146
# F1:0.157839479712
# MAP:0.120975332074
# NDCG:0.24011432212
# --------------------------------------------------------------------------------
# [1] iteration: 30
# --------------------------------------------------------------------------------
# Ranking Performance [1] (Top-10 On 1000 sampled users)
# Precision:0.1393
# Recall:0.219558488805
# F1:0.170454362623
# MAP:0.118242546296
# NDCG:0.213404939852
# Top 20
# Precision:0.1043
# Recall:0.324320114146
# F1:0.157839479712
# MAP:0.120975332074
# NDCG:0.24011432212
# --------------------------------------------------------------------------------
# Predicting [1]...
# IF_BPR [1] progress:0/1088
# IF_BPR [1] progress:100/1088
# IF_BPR [1] progress:200/1088
# IF_BPR [1] progress:300/1088
# IF_BPR [1] progress:400/1088
# IF_BPR [1] progress:500/1088
# IF_BPR [1] progress:600/1088
# IF_BPR [1] progress:700/1088
# IF_BPR [1] progress:800/1088
# IF_BPR [1] progress:900/1088
# IF_BPR [1] progress:1000/1088
# The result has been output to  /home/songxuan/python/RecQ/results .
# The result of IF_BPR [1]:
# Top 10
# Precision:0.138143382353
# Recall:0.221245622839
# F1:0.170086553724
# MAP:0.119920549817
# NDCG:0.214318129874
#
# Initializing model [2]...
# Preparing item sets...
# Building Model [2]...
# Kind Note: This method will probably take much time.
# Building weighted user-friend network...
# Generating random meta-path random walks... (Positive)
# pwalks: 38969
# nwalks: 39326
# Generating user embedding...
# User embedding generated.
# Constructing similarity matrix...
# 200 / 1384
# 400 / 1384
# 600 / 1384
# 800 / 1384
# 1000 / 1384
# 1200 / 1384
# 200 / 1384
# 400 / 1384
# 600 / 1384
# 800 / 1384
# 1000 / 1384
# 1200 / 1384
# Decomposing...
# IF_BPR [2] iteration 1: loss = 116403.8080, delta_loss = -116403.80804 learning_Rate = 0.05000
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1027
# Recall:0.167838545494
# F1:0.127427450981
# MAP:0.0845062325208
# NDCG:0.159957290036
# Top 20
# Precision:0.0829
# Recall:0.26409003736
# F1:0.126188430444
# MAP:0.0879681051844
# NDCG:0.187201415643
# --------------------------------------------------------------------------------
# [2] iteration: 1
# IF_BPR [2] iteration 2: loss = 113823.5532, delta_loss = 2580.25483 learning_Rate = 0.05000
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.099
# Recall:0.163808108294
# F1:0.123413260164
# MAP:0.080821619583
# NDCG:0.155582289514
# Top 20
# Precision:0.0816
# Recall:0.26296033061
# F1:0.124550396964
# MAP:0.0854135048415
# NDCG:0.184985738847
# --------------------------------------------------------------------------------
# [2] iteration: 2
# IF_BPR [2] iteration 3: loss = 113082.1975, delta_loss = 741.35576 learning_Rate = 0.05250
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.107
# Recall:0.177195073415
# F1:0.133428582189
# MAP:0.0850290414777
# NDCG:0.162436233747
# Top 20
# Precision:0.0831
# Recall:0.258485837325
# F1:0.125767351773
# MAP:0.0875701263742
# NDCG:0.185527336612
# --------------------------------------------------------------------------------
# [2] iteration: 3
# IF_BPR [2] iteration 4: loss = 112494.6275, delta_loss = 587.56997 learning_Rate = 0.05513
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1057
# Recall:0.168545878828
# F1:0.129922093767
# MAP:0.0867825272424
# NDCG:0.164042197572
# Top 20
# Precision:0.0853
# Recall:0.271255811298
# F1:0.129786810202
# MAP:0.091443567329
# NDCG:0.193185222748
# --------------------------------------------------------------------------------
# [2] iteration: 4
# IF_BPR [2] iteration 5: loss = 111862.1660, delta_loss = 632.46151 learning_Rate = 0.05788
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1099
# Recall:0.17694067107
# F1:0.135585931228
# MAP:0.0909924727576
# NDCG:0.170958181852
# Top 20
# Precision:0.08775
# Recall:0.27199148281
# F1:0.132691133812
# MAP:0.0940753172525
# NDCG:0.197720493952
# --------------------------------------------------------------------------------
# [2] iteration: 5
# IF_BPR [2] iteration 6: loss = 110912.3440, delta_loss = 949.82193 learning_Rate = 0.06078
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1172
# Recall:0.183588775517
# F1:0.143067868498
# MAP:0.0916857043651
# NDCG:0.174930652421
# Top 20
# Precision:0.092
# Recall:0.282968175917
# F1:0.138854835457
# MAP:0.0957748517541
# NDCG:0.20273387804
# --------------------------------------------------------------------------------
# [2] iteration: 6
# IF_BPR [2] iteration 7: loss = 110010.6361, delta_loss = 901.70796 learning_Rate = 0.06381
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1179
# Recall:0.189476280282
# F1:0.145354439352
# MAP:0.0997913547178
# NDCG:0.184245218357
# Top 20
# Precision:0.0935
# Recall:0.292932537716
# F1:0.141754068839
# MAP:0.103724618603
# NDCG:0.212524382902
# --------------------------------------------------------------------------------
# [2] iteration: 7
# IF_BPR [2] iteration 8: loss = 109547.5301, delta_loss = 463.10600 learning_Rate = 0.06700
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1217
# Recall:0.192155470113
# F1:0.149019679054
# MAP:0.102939840797
# NDCG:0.188716449155
# Top 20
# Precision:0.09435
# Recall:0.296029382631
# F1:0.143093480311
# MAP:0.105835593174
# NDCG:0.215817927425
# --------------------------------------------------------------------------------
# [2] iteration: 8
# IF_BPR [2] iteration 9: loss = 109146.5073, delta_loss = 401.02281 learning_Rate = 0.07036
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1208
# Recall:0.200323151243
# F1:0.150714992529
# MAP:0.0978569179894
# NDCG:0.185078072095
# Top 20
# Precision:0.09435
# Recall:0.299474316085
# F1:0.14349241816
# MAP:0.101682013062
# NDCG:0.212533819445
# --------------------------------------------------------------------------------
# [2] iteration: 9
# IF_BPR [2] iteration 10: loss = 108888.6639, delta_loss = 257.84337 learning_Rate = 0.07387
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1209
# Recall:0.203848821448
# F1:0.151780828045
# MAP:0.0998166189531
# NDCG:0.187360508495
# Top 20
# Precision:0.09505
# Recall:0.301232214331
# F1:0.14450369427
# MAP:0.104100138926
# NDCG:0.215091691125
# --------------------------------------------------------------------------------
# [2] iteration: 10
# IF_BPR [2] iteration 11: loss = 109525.9233, delta_loss = -637.25939 learning_Rate = 0.07757
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1175
# Recall:0.193711169794
# F1:0.146274071499
# MAP:0.103087962176
# NDCG:0.186526805704
# Top 20
# Precision:0.0937
# Recall:0.302994102018
# F1:0.14313571699
# MAP:0.108522642458
# NDCG:0.217270659934
# --------------------------------------------------------------------------------
# [2] iteration: 11
# IF_BPR [2] iteration 12: loss = 104865.0765, delta_loss = 4660.84676 learning_Rate = 0.03878
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1214
# Recall:0.193833837922
# F1:0.149295063492
# MAP:0.105319556091
# NDCG:0.191721507079
# Top 20
# Precision:0.0952
# Recall:0.300079042432
# F1:0.144543584521
# MAP:0.109798956995
# NDCG:0.220665494984
# --------------------------------------------------------------------------------
# [2] iteration: 12
# IF_BPR [2] iteration 13: loss = 104150.9978, delta_loss = 714.07875 learning_Rate = 0.04072
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1224
# Recall:0.205147472468
# F1:0.153321596048
# MAP:0.104791805398
# NDCG:0.193480510217
# Top 20
# Precision:0.0953
# Recall:0.299555485782
# F1:0.144597903906
# MAP:0.108393223323
# NDCG:0.219602188803
# --------------------------------------------------------------------------------
# [2] iteration: 13
# IF_BPR [2] iteration 14: loss = 104047.7169, delta_loss = 103.28089 learning_Rate = 0.04276
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1228
# Recall:0.201572889868
# F1:0.152621576272
# MAP:0.107113965734
# NDCG:0.195230202804
# Top 20
# Precision:0.0941
# Recall:0.297433819429
# F1:0.142968607152
# MAP:0.110488097439
# NDCG:0.220832711004
# --------------------------------------------------------------------------------
# [2] iteration: 14
# IF_BPR [2] iteration 15: loss = 103875.0507, delta_loss = 172.66619 learning_Rate = 0.04490
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1229
# Recall:0.198894134777
# F1:0.15192377065
# MAP:0.106194058799
# NDCG:0.193053276233
# Top 20
# Precision:0.09525
# Recall:0.301633147398
# F1:0.144780938561
# MAP:0.109481146483
# NDCG:0.220338588164
# --------------------------------------------------------------------------------
# [2] iteration: 15
# IF_BPR [2] iteration 16: loss = 103902.9153, delta_loss = -27.86459 learning_Rate = 0.04714
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1231
# Recall:0.203179231173
# F1:0.153312628986
# MAP:0.107740762629
# NDCG:0.194289806274
# Top 20
# Precision:0.09625
# Recall:0.305335482071
# F1:0.146362562699
# MAP:0.112032546858
# NDCG:0.222759979212
# --------------------------------------------------------------------------------
# [2] iteration: 16
# IF_BPR [2] iteration 17: loss = 101832.5469, delta_loss = 2070.36836 learning_Rate = 0.02357
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1253
# Recall:0.205320526859
# F1:0.155626526035
# MAP:0.108244239261
# NDCG:0.197503652647
# Top 20
# Precision:0.09735
# Recall:0.308331626117
# F1:0.147978522418
# MAP:0.1128002879
# NDCG:0.225863551223
# --------------------------------------------------------------------------------
# [2] iteration: 17
# IF_BPR [2] iteration 18: loss = 100956.9012, delta_loss = 875.64573 learning_Rate = 0.02475
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1259
# Recall:0.208254743871
# F1:0.156928924304
# MAP:0.109753276329
# NDCG:0.198289032019
# Top 20
# Precision:0.09785
# Recall:0.304071912359
# F1:0.148055807406
# MAP:0.113414228103
# NDCG:0.22482296938
# --------------------------------------------------------------------------------
# [2] iteration: 18
# IF_BPR [2] iteration 19: loss = 101217.9633, delta_loss = -261.06206 learning_Rate = 0.02599
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1227
# Recall:0.205557626277
# F1:0.153671499001
# MAP:0.113712333711
# NDCG:0.201033441307
# Top 20
# Precision:0.0976
# Recall:0.304971729273
# F1:0.147875464732
# MAP:0.117689961124
# NDCG:0.229647981455
# --------------------------------------------------------------------------------
# [2] iteration: 19
# IF_BPR [2] iteration 20: loss = 99939.4952, delta_loss = 1278.46801 learning_Rate = 0.01299
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1258
# Recall:0.206958392835
# F1:0.156482098599
# MAP:0.112428539462
# NDCG:0.201717217178
# Top 20
# Precision:0.0987
# Recall:0.310408987007
# F1:0.149776064524
# MAP:0.116532790935
# NDCG:0.230422263427
# --------------------------------------------------------------------------------
# [2] iteration: 20
# IF_BPR [2] iteration 21: loss = 99757.4608, delta_loss = 182.03448 learning_Rate = 0.01364
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1265
# Recall:0.212029710156
# F1:0.158460291845
# MAP:0.112252443468
# NDCG:0.20224185552
# Top 20
# Precision:0.09855
# Recall:0.304759934648
# F1:0.148938020016
# MAP:0.116048616516
# NDCG:0.228433186714
# --------------------------------------------------------------------------------
# [2] iteration: 21
# IF_BPR [2] iteration 22: loss = 99503.3019, delta_loss = 254.15883 learning_Rate = 0.01433
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1274
# Recall:0.211236991363
# F1:0.158940655546
# MAP:0.113299194696
# NDCG:0.203719689914
# Top 20
# Precision:0.1
# Recall:0.309195499527
# F1:0.151123607119
# MAP:0.117271542195
# NDCG:0.231236048743
# --------------------------------------------------------------------------------
# [2] iteration: 22
# IF_BPR [2] iteration 23: loss = 99666.7941, delta_loss = -163.49214 learning_Rate = 0.01504
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1269
# Recall:0.211428096014
# F1:0.158604772706
# MAP:0.114204133755
# NDCG:0.204300376097
# Top 20
# Precision:0.09905
# Recall:0.309651585935
# F1:0.15008989758
# MAP:0.117338116629
# NDCG:0.231377251679
# --------------------------------------------------------------------------------
# [2] iteration: 23
# IF_BPR [2] iteration 24: loss = 98868.0758, delta_loss = 798.71828 learning_Rate = 0.00752
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1282
# Recall:0.214952376424
# F1:0.160610251019
# MAP:0.114653469545
# NDCG:0.206242330894
# Top 20
# Precision:0.0998
# Recall:0.313270811068
# F1:0.151375629102
# MAP:0.117968621944
# NDCG:0.233067350436
# --------------------------------------------------------------------------------
# [2] iteration: 24
# IF_BPR [2] iteration 25: loss = 98789.6793, delta_loss = 78.39647 learning_Rate = 0.00790
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1274
# Recall:0.210847800368
# F1:0.158830358912
# MAP:0.11521977151
# NDCG:0.206109856097
# Top 20
# Precision:0.10035
# Recall:0.313297331838
# F1:0.152010588877
# MAP:0.119147189167
# NDCG:0.234526512077
# --------------------------------------------------------------------------------
# [2] iteration: 25
# IF_BPR [2] iteration 26: loss = 98796.3266, delta_loss = -6.64728 learning_Rate = 0.00829
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1282
# Recall:0.208346421797
# F1:0.158730026793
# MAP:0.112726918462
# NDCG:0.203412475903
# Top 20
# Precision:0.10025
# Recall:0.314992098152
# F1:0.152094202299
# MAP:0.117017382669
# NDCG:0.232439995374
# --------------------------------------------------------------------------------
# [2] iteration: 26
# IF_BPR [2] iteration 27: loss = 98266.6728, delta_loss = 529.65376 learning_Rate = 0.00415
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.129
# Recall:0.209977319542
# F1:0.159816439976
# MAP:0.11384091821
# NDCG:0.20502284496
# Top 20
# Precision:0.1002
# Recall:0.313149311673
# F1:0.15182103922
# MAP:0.11774754473
# NDCG:0.232738802756
# --------------------------------------------------------------------------------
# [2] iteration: 27
# IF_BPR [2] iteration 28: loss = 98419.2148, delta_loss = -152.54195 learning_Rate = 0.00435
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1299
# Recall:0.21194438284
# F1:0.16107665776
# MAP:0.113553976127
# NDCG:0.205467764174
# Top 20
# Precision:0.1002
# Recall:0.313719243932
# F1:0.151887928396
# MAP:0.11700084605
# NDCG:0.232350287785
# --------------------------------------------------------------------------------
# [2] iteration: 28
# IF_BPR [2] iteration 29: loss = 98092.6428, delta_loss = 326.57199 learning_Rate = 0.00218
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1312
# Recall:0.213903384124
# F1:0.162641835972
# MAP:0.114517142385
# NDCG:0.206868113513
# Top 20
# Precision:0.10025
# Recall:0.313715720984
# F1:0.151944953094
# MAP:0.117569485106
# NDCG:0.232829143385
# --------------------------------------------------------------------------------
# [2] iteration: 29
# IF_BPR [2] iteration 30: loss = 98119.3164, delta_loss = -26.67358 learning_Rate = 0.00229
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1309
# Recall:0.213008173448
# F1:0.162152411935
# MAP:0.113215223608
# NDCG:0.205320901535
# Top 20
# Precision:0.10085
# Recall:0.316362430185
# F1:0.152944393675
# MAP:0.116757421388
# NDCG:0.232697568432
# --------------------------------------------------------------------------------
# [2] iteration: 30
# --------------------------------------------------------------------------------
# Ranking Performance [2] (Top-10 On 1000 sampled users)
# Precision:0.1309
# Recall:0.213008173448
# F1:0.162152411935
# MAP:0.113215223608
# NDCG:0.205320901535
# Top 20
# Precision:0.10085
# Recall:0.316362430185
# F1:0.152944393675
# MAP:0.116757421388
# NDCG:0.232697568432
# --------------------------------------------------------------------------------
# Predicting [2]...
# IF_BPR [2] progress:0/1099
# IF_BPR [2] progress:100/1099
# IF_BPR [2] progress:200/1099
# IF_BPR [2] progress:300/1099
# IF_BPR [2] progress:400/1099
# IF_BPR [2] progress:500/1099
# IF_BPR [2] progress:600/1099
# IF_BPR [2] progress:700/1099
# IF_BPR [2] progress:800/1099
# IF_BPR [2] progress:900/1099
# IF_BPR [2] progress:1000/1099
# The result has been output to  /home/songxuan/python/RecQ/results .
# The result of IF_BPR [2]:
# Top 10
# Precision:0.128116469518
# Recall:0.209924800821
# F1:0.159121543464
# MAP:0.111502904333
# NDCG:0.202204102679
#
# Initializing model [3]...
# Preparing item sets...
# Building Model [3]...
# Kind Note: This method will probably take much time.
# Building weighted user-friend network...
# Generating random meta-path random walks... (Positive)
# pwalks: 37357
# nwalks: 37578
# Generating user embedding...
# User embedding generated.
# Constructing similarity matrix...
# 200 / 1384
# 400 / 1384
# 600 / 1384
# 800 / 1384
# 1000 / 1384
# 1200 / 1384
# 200 / 1384
# 400 / 1384
# 600 / 1384
# 800 / 1384
# 1000 / 1384
# 1200 / 1384
# Decomposing...
# IF_BPR [3] iteration 1: loss = 116567.0796, delta_loss = -116567.07958 learning_Rate = 0.05000
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.0994
# Recall:0.15857522958
# F1:0.122200707765
# MAP:0.0865892691799
# NDCG:0.158131763028
# Top 20
# Precision:0.0811
# Recall:0.258949132483
# F1:0.123516119515
# MAP:0.0886414403415
# NDCG:0.185301566195
# --------------------------------------------------------------------------------
# [3] iteration: 1
# IF_BPR [3] iteration 2: loss = 113774.6316, delta_loss = 2792.44802 learning_Rate = 0.05000
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1031
# Recall:0.162757348968
# F1:0.126235236632
# MAP:0.0859600207861
# NDCG:0.160662178988
# Top 20
# Precision:0.0824
# Recall:0.254064822298
# F1:0.124440595093
# MAP:0.0876042566183
# NDCG:0.185017263963
# --------------------------------------------------------------------------------
# [3] iteration: 2
# IF_BPR [3] iteration 3: loss = 113128.8156, delta_loss = 645.81596 learning_Rate = 0.05250
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1047
# Recall:0.166332978597
# F1:0.12850881062
# MAP:0.086236412352
# NDCG:0.161740719807
# Top 20
# Precision:0.0826
# Recall:0.257860226139
# F1:0.125120369687
# MAP:0.0875294862464
# NDCG:0.185395894116
# --------------------------------------------------------------------------------
# [3] iteration: 3
# IF_BPR [3] iteration 4: loss = 112625.7263, delta_loss = 503.08932 learning_Rate = 0.05513
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1019
# Recall:0.157270502222
# F1:0.123670433471
# MAP:0.0836683360103
# NDCG:0.157178742699
# Top 20
# Precision:0.08595
# Recall:0.265037097966
# F1:0.129804991136
# MAP:0.0877436658574
# NDCG:0.187945817926
# --------------------------------------------------------------------------------
# [3] iteration: 4
# IF_BPR [3] iteration 5: loss = 111789.7016, delta_loss = 836.02472 learning_Rate = 0.05788
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1107
# Recall:0.163484278255
# F1:0.132011286117
# MAP:0.0910991983182
# NDCG:0.167673780355
# Top 20
# Precision:0.08995
# Recall:0.276372091344
# F1:0.135725746297
# MAP:0.0943719545913
# NDCG:0.197985289294
# --------------------------------------------------------------------------------
# [3] iteration: 5
# IF_BPR [3] iteration 6: loss = 110576.2630, delta_loss = 1213.43859 learning_Rate = 0.06078
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1193
# Recall:0.187354922428
# F1:0.14577585821
# MAP:0.092381997512
# NDCG:0.175144176674
# Top 20
# Precision:0.09315
# Recall:0.285635495389
# F1:0.140485560928
# MAP:0.094080154807
# NDCG:0.200413287517
# --------------------------------------------------------------------------------
# [3] iteration: 6
# IF_BPR [3] iteration 7: loss = 109840.1280, delta_loss = 736.13501 learning_Rate = 0.06381
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1206
# Recall:0.188650121522
# F1:0.147137886599
# MAP:0.096397568972
# NDCG:0.181496269054
# Top 20
# Precision:0.0954
# Recall:0.295608633262
# F1:0.144247779789
# MAP:0.0991635874625
# NDCG:0.209452269097
# --------------------------------------------------------------------------------
# [3] iteration: 7
# IF_BPR [3] iteration 8: loss = 109066.5084, delta_loss = 773.61955 learning_Rate = 0.06700
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1217
# Recall:0.192160926554
# F1:0.149021319846
# MAP:0.0996819356261
# NDCG:0.184275143939
# Top 20
# Precision:0.0959
# Recall:0.290458259532
# F1:0.144192320997
# MAP:0.101925313134
# NDCG:0.210468548026
# --------------------------------------------------------------------------------
# [3] iteration: 8
# IF_BPR [3] iteration 9: loss = 108822.1553, delta_loss = 244.35307 learning_Rate = 0.07036
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1226
# Recall:0.193187630188
# F1:0.150004630941
# MAP:0.104203151612
# NDCG:0.189009310879
# Top 20
# Precision:0.0945
# Recall:0.291987297582
# F1:0.142787614466
# MAP:0.105428910204
# NDCG:0.213753853582
# --------------------------------------------------------------------------------
# [3] iteration: 9
# IF_BPR [3] iteration 10: loss = 108721.4871, delta_loss = 100.66823 learning_Rate = 0.07387
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1189
# Recall:0.192310949881
# F1:0.146947091351
# MAP:0.102905458869
# NDCG:0.18619963838
# Top 20
# Precision:0.09575
# Recall:0.295101740267
# F1:0.144586751034
# MAP:0.105959871224
# NDCG:0.214630135615
# --------------------------------------------------------------------------------
# [3] iteration: 10
# IF_BPR [3] iteration 11: loss = 109163.8654, delta_loss = -442.37824 learning_Rate = 0.07757
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1162
# Recall:0.187457002984
# F1:0.143467817522
# MAP:0.100271257401
# NDCG:0.182673507003
# Top 20
# Precision:0.09335
# Recall:0.291123761996
# F1:0.141369351402
# MAP:0.103876763546
# NDCG:0.211076105261
# --------------------------------------------------------------------------------
# [3] iteration: 11
# IF_BPR [3] iteration 12: loss = 104492.2487, delta_loss = 4671.61665 learning_Rate = 0.03878
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1215
# Recall:0.197511456239
# F1:0.150450032209
# MAP:0.104651197562
# NDCG:0.190109265066
# Top 20
# Precision:0.0955
# Recall:0.296319459611
# F1:0.144446671541
# MAP:0.107502075374
# NDCG:0.216598261997
# --------------------------------------------------------------------------------
# [3] iteration: 12
# IF_BPR [3] iteration 13: loss = 103999.4062, delta_loss = 492.84245 learning_Rate = 0.04072
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1227
# Recall:0.194855840149
# F1:0.150580203942
# MAP:0.102981560374
# NDCG:0.188053951591
# Top 20
# Precision:0.09635
# Recall:0.300473756533
# F1:0.145911861199
# MAP:0.106143002621
# NDCG:0.216119257215
# --------------------------------------------------------------------------------
# [3] iteration: 13
# IF_BPR [3] iteration 14: loss = 103766.7112, delta_loss = 232.69502 learning_Rate = 0.04276
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1207
# Recall:0.201217081052
# F1:0.150889176825
# MAP:0.107191869331
# NDCG:0.193580265194
# Top 20
# Precision:0.09585
# Recall:0.298530657723
# F1:0.145109365697
# MAP:0.10990534211
# NDCG:0.219886168602
# --------------------------------------------------------------------------------
# [3] iteration: 14
# IF_BPR [3] iteration 15: loss = 103700.3583, delta_loss = 66.35288 learning_Rate = 0.04490
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1203
# Recall:0.197581017195
# F1:0.149546497481
# MAP:0.106270060469
# NDCG:0.192732318269
# Top 20
# Precision:0.0965
# Recall:0.304772254784
# F1:0.146586374891
# MAP:0.109765735853
# NDCG:0.221913756265
# --------------------------------------------------------------------------------
# [3] iteration: 15
# IF_BPR [3] iteration 16: loss = 103657.8784, delta_loss = 42.47997 learning_Rate = 0.04714
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1216
# Recall:0.193770569306
# F1:0.149427394442
# MAP:0.103474416415
# NDCG:0.188971140925
# Top 20
# Precision:0.09575
# Recall:0.298299416612
# F1:0.144967447922
# MAP:0.106180949017
# NDCG:0.216364408375
# --------------------------------------------------------------------------------
# [3] iteration: 16
# IF_BPR [3] iteration 17: loss = 103875.5387, delta_loss = -217.66031 learning_Rate = 0.04950
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1201
# Recall:0.199569467858
# F1:0.149956724052
# MAP:0.108474884732
# NDCG:0.195495304579
# Top 20
# Precision:0.0948
# Recall:0.295993922357
# F1:0.143606244796
# MAP:0.110997878801
# NDCG:0.220984161957
# --------------------------------------------------------------------------------
# [3] iteration: 17
# IF_BPR [3] iteration 18: loss = 101253.7125, delta_loss = 2621.82617 learning_Rate = 0.02475
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1256
# Recall:0.204810305368
# F1:0.155710484427
# MAP:0.111979969608
# NDCG:0.199904028279
# Top 20
# Precision:0.0975
# Recall:0.299759426309
# F1:0.147140846155
# MAP:0.114204064851
# NDCG:0.22428154637
# --------------------------------------------------------------------------------
# [3] iteration: 18
# IF_BPR [3] iteration 19: loss = 100967.9905, delta_loss = 285.72203 learning_Rate = 0.02599
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1254
# Recall:0.204257296282
# F1:0.155396924276
# MAP:0.111748644022
# NDCG:0.199411091614
# Top 20
# Precision:0.09855
# Recall:0.304207080255
# F1:0.148871909292
# MAP:0.114521562899
# NDCG:0.226039526618
# --------------------------------------------------------------------------------
# [3] iteration: 19
# IF_BPR [3] iteration 20: loss = 100911.0192, delta_loss = 56.97132 learning_Rate = 0.02729
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.1268
# Recall:0.207272614832
# F1:0.15734404075
# MAP:0.11159864418
# NDCG:0.199949675381
# Top 20
# Precision:0.0975
# Recall:0.3015354376
# F1:0.147353855802
# MAP:0.113093322632
# NDCG:0.223901129334
# --------------------------------------------------------------------------------
# [3] iteration: 20
# IF_BPR [3] iteration 21: loss = 101118.2254, delta_loss = -207.20628 learning_Rate = 0.02865
# --------------------------------------------------------------------------------
# Ranking Performance [3] (Top-10 On 1000 sampled users)
# Precision:0.125
# Recall:0.202831687996
# ...
# NDCG:0.183221144734
# --------------------------------------------------------------------------------
# [5] iteration: 2
# IF_BPR [5] iteration 3: loss = 113978.8715, delta_loss = 334.26424 learning_Rate = 0.05250
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1024
# Recall:0.158493227326
# F1:0.124416464502
# MAP:0.0851170389267
# NDCG:0.15840766378
# Top 20
# Precision:0.0841
# Recall:0.2613560158
# F1:0.127252326916
# MAP:0.0885451496147
# NDCG:0.186974502272
# --------------------------------------------------------------------------------
# [5] iteration: 3
# IF_BPR [5] iteration 4: loss = 113263.0972, delta_loss = 715.77433 learning_Rate = 0.05513
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.105
# Recall:0.163193547638
# F1:0.127783256927
# MAP:0.0835868096498
# NDCG:0.158792360717
# Top 20
# Precision:0.085
# Recall:0.263788576518
# F1:0.12857089087
# MAP:0.0873137862014
# NDCG:0.186399261074
# --------------------------------------------------------------------------------
# [5] iteration: 4
# IF_BPR [5] iteration 5: loss = 112411.9582, delta_loss = 851.13901 learning_Rate = 0.05788
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1121
# Recall:0.178201606065
# F1:0.13762514311
# MAP:0.0961175932225
# NDCG:0.175306595388
# Top 20
# Precision:0.08825
# Recall:0.276762495758
# F1:0.133827145835
# MAP:0.0979490134345
# NDCG:0.20086920488
# --------------------------------------------------------------------------------
# [5] iteration: 5
# IF_BPR [5] iteration 6: loss = 111438.6754, delta_loss = 973.28276 learning_Rate = 0.06078
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1189
# Recall:0.188698351601
# F1:0.145880066577
# MAP:0.0996644217687
# NDCG:0.182991737632
# Top 20
# Precision:0.09275
# Recall:0.285005254726
# F1:0.139954306632
# MAP:0.101225063835
# NDCG:0.2077364497
# --------------------------------------------------------------------------------
# [5] iteration: 6
# IF_BPR [5] iteration 7: loss = 110631.8475, delta_loss = 806.82786 learning_Rate = 0.06381
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1153
# Recall:0.181005845185
# F1:0.140867784345
# MAP:0.0932827557319
# NDCG:0.175131159361
# Top 20
# Precision:0.09395
# Recall:0.294711345926
# F1:0.142479468257
# MAP:0.096958572314
# NDCG:0.206204602115
# --------------------------------------------------------------------------------
# [5] iteration: 7
# IF_BPR [5] iteration 8: loss = 110050.0937, delta_loss = 581.75382 learning_Rate = 0.06700
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1204
# Recall:0.189823631568
# F1:0.147343805662
# MAP:0.100804688524
# NDCG:0.184311230928
# Top 20
# Precision:0.09635
# Recall:0.293813699103
# F1:0.145113192097
# MAP:0.103692737029
# NDCG:0.211830136794
# --------------------------------------------------------------------------------
# [5] iteration: 8
# IF_BPR [5] iteration 9: loss = 109951.7199, delta_loss = 98.37383 learning_Rate = 0.07036
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1216
# Recall:0.187642008135
# F1:0.147569008019
# MAP:0.099373593317
# NDCG:0.183470221438
# Top 20
# Precision:0.0952
# Recall:0.292870937417
# F1:0.143691838547
# MAP:0.101314440363
# NDCG:0.210101591262
# --------------------------------------------------------------------------------
# [5] iteration: 9
# IF_BPR [5] iteration 10: loss = 109709.5612, delta_loss = 242.15870 learning_Rate = 0.07387
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1199
# Recall:0.189597236188
# F1:0.146900882857
# MAP:0.101792025699
# NDCG:0.185390560795
# Top 20
# Precision:0.09265
# Recall:0.288158713801
# F1:0.140216879846
# MAP:0.103174039078
# NDCG:0.209684067365
# --------------------------------------------------------------------------------
# [5] iteration: 10
# IF_BPR [5] iteration 11: loss = 110477.3899, delta_loss = -767.82870 learning_Rate = 0.07757
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1186
# Recall:0.188529397647
# F1:0.145603688427
# MAP:0.0989022907218
# NDCG:0.181754743617
# Top 20
# Precision:0.09365
# Recall:0.292579515881
# F1:0.141884918348
# MAP:0.101855522397
# NDCG:0.209633955595
# --------------------------------------------------------------------------------
# [5] iteration: 11
# IF_BPR [5] iteration 12: loss = 105569.6697, delta_loss = 4907.72020 learning_Rate = 0.03878
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1256
# Recall:0.201572960901
# F1:0.154765625004
# MAP:0.108316905707
# NDCG:0.195181734535
# Top 20
# Precision:0.0954
# Recall:0.297017311142
# F1:0.144414890365
# MAP:0.109707240545
# NDCG:0.218564848015
# --------------------------------------------------------------------------------
# [5] iteration: 12
# IF_BPR [5] iteration 13: loss = 105171.4326, delta_loss = 398.23711 learning_Rate = 0.04072
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1244
# Recall:0.193647180967
# F1:0.151485130219
# MAP:0.102686306847
# NDCG:0.188447666385
# Top 20
# Precision:0.09655
# Recall:0.293778941105
# F1:0.145335658091
# MAP:0.105130724645
# NDCG:0.214008047956
# --------------------------------------------------------------------------------
# [5] iteration: 13
# IF_BPR [5] iteration 14: loss = 104709.7969, delta_loss = 461.63566 learning_Rate = 0.04276
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1249
# Recall:0.201761923078
# F1:0.154288347751
# MAP:0.10448454995
# NDCG:0.19154608229
# Top 20
# Precision:0.097
# Recall:0.297681753703
# F1:0.146321079393
# MAP:0.106101721149
# NDCG:0.216019143569
# --------------------------------------------------------------------------------
# [5] iteration: 14
# IF_BPR [5] iteration 15: loss = 104767.0162, delta_loss = -57.21924 learning_Rate = 0.04490
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1252
# Recall:0.205227527958
# F1:0.155522674876
# MAP:0.107040090388
# NDCG:0.195334247195
# Top 20
# Precision:0.09695
# Recall:0.297929154962
# F1:0.146294030519
# MAP:0.108729974784
# NDCG:0.218605991783
# --------------------------------------------------------------------------------
# [5] iteration: 15
# IF_BPR [5] iteration 16: loss = 102358.7333, delta_loss = 2408.28283 learning_Rate = 0.02245
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1288
# Recall:0.210347005113
# F1:0.159769621138
# MAP:0.107689486017
# NDCG:0.196299452455
# Top 20
# Precision:0.0995
# Recall:0.308366596618
# F1:0.150453489538
# MAP:0.108883436808
# NDCG:0.220962630351
# --------------------------------------------------------------------------------
# [5] iteration: 16
# IF_BPR [5] iteration 17: loss = 101914.4542, delta_loss = 444.27915 learning_Rate = 0.02357
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1254
# Recall:0.205316001874
# F1:0.155702333658
# MAP:0.107999643487
# NDCG:0.195173614112
# Top 20
# Precision:0.0991
# Recall:0.306191564203
# F1:0.149737061871
# MAP:0.110225865776
# NDCG:0.221799061397
# --------------------------------------------------------------------------------
# [5] iteration: 17
# IF_BPR [5] iteration 18: loss = 101871.5049, delta_loss = 42.94932 learning_Rate = 0.02475
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1255
# Recall:0.201400928077
# F1:0.154639001011
# MAP:0.105991506992
# NDCG:0.194623680271
# Top 20
# Precision:0.09935
# Recall:0.304245852544
# F1:0.149787592017
# MAP:0.10870267578
# NDCG:0.221627688417
# --------------------------------------------------------------------------------
# [5] iteration: 18
# IF_BPR [5] iteration 19: loss = 101801.7517, delta_loss = 69.75318 learning_Rate = 0.02599
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1285
# Recall:0.212836582722
# F1:0.160249456192
# MAP:0.111217608655
# NDCG:0.202145580616
# Top 20
# Precision:0.09905
# Recall:0.305952748005
# F1:0.149651427499
# MAP:0.112545644821
# NDCG:0.225357356607
# --------------------------------------------------------------------------------
# [5] iteration: 19
# IF_BPR [5] iteration 20: loss = 101828.8255, delta_loss = -27.07377 learning_Rate = 0.02729
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1297
# Recall:0.20914673308
# F1:0.160109740672
# MAP:0.110788872984
# NDCG:0.199921109895
# Top 20
# Precision:0.10015
# Recall:0.305035772411
# F1:0.150791734
# MAP:0.112068111318
# NDCG:0.223661781724
# --------------------------------------------------------------------------------
# [5] iteration: 20
# IF_BPR [5] iteration 21: loss = 100784.0801, delta_loss = 1044.74533 learning_Rate = 0.01364
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.129
# Recall:0.200551272185
# F1:0.15700812769
# MAP:0.108484127299
# NDCG:0.195904341828
# Top 20
# Precision:0.10095
# Recall:0.305845071046
# F1:0.15179662744
# MAP:0.110656122127
# NDCG:0.222417595249
# --------------------------------------------------------------------------------
# [5] iteration: 21
# IF_BPR [5] iteration 22: loss = 100481.8008, delta_loss = 302.27937 learning_Rate = 0.01433
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1291
# Recall:0.206291628755
# F1:0.158812844382
# MAP:0.109117718884
# NDCG:0.197485798955
# Top 20
# Precision:0.10085
# Recall:0.306153323864
# F1:0.151721427818
# MAP:0.110929944003
# NDCG:0.222830037673
# --------------------------------------------------------------------------------
# [5] iteration: 22
# IF_BPR [5] iteration 23: loss = 100511.2593, delta_loss = -29.45854 learning_Rate = 0.01504
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1286
# Recall:0.206290351348
# F1:0.15843358327
# MAP:0.109022029478
# NDCG:0.198487142225
# Top 20
# Precision:0.10065
# Recall:0.308439350522
# F1:0.151773301311
# MAP:0.110848140631
# NDCG:0.22467388681
# --------------------------------------------------------------------------------
# [5] iteration: 23
# IF_BPR [5] iteration 24: loss = 99747.3196, delta_loss = 763.93968 learning_Rate = 0.00752
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1302
# Recall:0.208519550218
# F1:0.160305157591
# MAP:0.110549537195
# NDCG:0.199711429737
# Top 20
# Precision:0.1016
# Recall:0.311193701515
# F1:0.1531868338
# MAP:0.112329524603
# NDCG:0.226038225885
# --------------------------------------------------------------------------------
# [5] iteration: 24
# IF_BPR [5] iteration 25: loss = 99783.6527, delta_loss = -36.33310 learning_Rate = 0.00790
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1291
# Recall:0.205176332792
# F1:0.158481244198
# MAP:0.109270821208
# NDCG:0.198281562279
# Top 20
# Precision:0.1023
# Recall:0.312167682246
# F1:0.154100091572
# MAP:0.111565278702
# NDCG:0.22599953585
# --------------------------------------------------------------------------------
# [5] iteration: 25
# IF_BPR [5] iteration 26: loss = 99268.0709, delta_loss = 515.58179 learning_Rate = 0.00395
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1313
# Recall:0.208605936399
# F1:0.161161995223
# MAP:0.111732467089
# NDCG:0.201595922011
# Top 20
# Precision:0.1023
# Recall:0.312439429485
# F1:0.154133180325
# MAP:0.113093472567
# NDCG:0.227475641616
# --------------------------------------------------------------------------------
# [5] iteration: 26
# IF_BPR [5] iteration 27: loss = 99276.8780, delta_loss = -8.80708 learning_Rate = 0.00415
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1314
# Recall:0.207533043745
# F1:0.160915805947
# MAP:0.111017329932
# NDCG:0.200304667308
# Top 20
# Precision:0.1032
# Recall:0.313843052712
# F1:0.155324985415
# MAP:0.113028999324
# NDCG:0.227477863291
# --------------------------------------------------------------------------------
# [5] iteration: 27
# IF_BPR [5] iteration 28: loss = 98901.8076, delta_loss = 375.07040 learning_Rate = 0.00207
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1325
# Recall:0.209920645957
# F1:0.162457993802
# MAP:0.111233821807
# NDCG:0.201430009481
# Top 20
# Precision:0.10365
# Recall:0.31606204499
# F1:0.156106222608
# MAP:0.113001472294
# NDCG:0.228369305223
# --------------------------------------------------------------------------------
# [5] iteration: 28
# IF_BPR [5] iteration 29: loss = 98923.6848, delta_loss = -21.87720 learning_Rate = 0.00218
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1319
# Recall:0.208583697356
# F1:0.161606502132
# MAP:0.111297904699
# NDCG:0.201217210166
# Top 20
# Precision:0.1034
# Recall:0.315666987937
# F1:0.155774458462
# MAP:0.113336282681
# NDCG:0.228558693428
# --------------------------------------------------------------------------------
# [5] iteration: 29
# IF_BPR [5] iteration 30: loss = 98802.9860, delta_loss = 120.69881 learning_Rate = 0.00109
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1324
# Recall:0.208723190133
# F1:0.162023287615
# MAP:0.111199128559
# NDCG:0.201273989222
# Top 20
# Precision:0.1033
# Recall:0.315870351691
# F1:0.155685664304
# MAP:0.113102135032
# NDCG:0.228310988758
# --------------------------------------------------------------------------------
# [5] iteration: 30
# --------------------------------------------------------------------------------
# Ranking Performance [5] (Top-10 On 1000 sampled users)
# Precision:0.1324
# Recall:0.208723190133
# F1:0.162023287615
# MAP:0.111199128559
# NDCG:0.201273989222
# Top 20
# Precision:0.1033
# Recall:0.315870351691
# F1:0.155685664304
# MAP:0.113102135032
# NDCG:0.228310988758
# --------------------------------------------------------------------------------
# Predicting [5]...
# IF_BPR [5] progress:0/1105
# IF_BPR [5] progress:100/1105
# IF_BPR [5] progress:200/1105
# IF_BPR [5] progress:300/1105
# IF_BPR [5] progress:400/1105
# IF_BPR [5] progress:500/1105
# IF_BPR [5] progress:600/1105
# IF_BPR [5] progress:700/1105
# IF_BPR [5] progress:800/1105
# IF_BPR [5] progress:900/1105
# IF_BPR [5] progress:1000/1105
# IF_BPR [5] progress:1100/1105
# The result has been output to  /home/songxuan/python/RecQ/results .
# The result of IF_BPR [5]:
# Top 10
# Precision:0.129321266968
# Recall:0.206607735624
# F1:0.15907393485
# MAP:0.108689460115
# NDCG:0.196986042212
#
# The result of 5-fold cross validation:
# Top 10
# Precision:0.129980755868
# Recall:0.210458767547
# F1:0.160701602667
# MAP:0.114026882107
# NDCG:0.203988081398
#
# Run time: 1280.569697 s
